# %% [markdown]
# # TLT DetectNet_v2 example usecase
#
# This notebook shows an example usecase of Object Detection using DetectNet_v2 in the Transfer Learning Toolkit.
#
# 0. [Set up env variables](#head-0)
# 1. [Prepare dataset and pre-trained model](#head-1)
#     1. [Verify downloaded dataset](#head-1-1)
#     1. [Prepare tfrecords from kitti format dataset](#head-1-2)
#     2. [Download pre-trained model](#head-1-3)
# 2. [Provide training specification](#head-2)
# 3. [Run TLT training](#head-3)
# 4. [Evaluate trained models](#head-4)
# 5. [Prune trained models](#head-5)
# 6. [Retrain pruned models](#head-6)
# 7. [Evaluate retrained model](#head-7)
# 8. [Visualize inferences](#head-8)
# 9. [Deploy](#head-9)
#     1. [Int8 Optimization](#head-9-1)
#     2. [Generate TensorRT engine](#head-9-2)
# 10. [Verify Deployed Model](#head-10)
#     1. [Inference using TensorRT engine](#head-10-1)

# %% [markdown]
# ## 0. Set up env variables <a class="anchor" id="head-0"></a>
# When using the purpose-built pretrained models from NGC, please make sure to set the `$KEY` environment variable to the key as mentioned in the model overview. Failing to do so, can lead to errors when trying to load them as pretrained models.
#
# *Note: Please make sure to remove any stray artifacts/files from the `$USER_EXPERIMENT_DIR` or `$DATA_DOWNLOAD_DIR` paths as mentioned below, that may have been generated from previous experiments. Having checkpoint files etc may interfere with creating a training graph for a new experiment.*

# %%
# Setting up env variables for cleaner command line commands.
# %env KEY=cWMyOGdvczdua3N1Z2lrcmdmMHFldWppdmc6NGJhNmM4Y2EtYzc1Yi00ZmJlLTk0ZmYtMTJjYTdkZWJiOWRi
# %env USER_EXPERIMENT_DIR=/home/jovyan/detectnet_v2
# %env DATA_DOWNLOAD_DIR=/home/jovyan/data
# %env SPECS_DIR=/home/jovyan/specs
# Out:
# env: KEY=cWMyOGdvczdua3N1Z2lrcmdmMHFldWppdmc6NGJhNmM4Y2EtYzc1Yi00ZmJlLTk0ZmYtMTJjYTdkZWJiOWRi
# env: USER_EXPERIMENT_DIR=/home/jovyan/detectnet_v2
# env: DATA_DOWNLOAD_DIR=/home/jovyan/data
# env: SPECS_DIR=/home/jovyan/specs

# %% [markdown]
# ## 1. Prepare dataset and pre-trained model <a class="anchor" id="head-1"></a>

# %% [markdown]
# We will be using the kitti object detection dataset for this example. To find more details, please visit http://www.cvlibs.net/datasets/kitti/eval_object.php?obj_benchmark=2d. Please download both, the left color images of the object dataset from [here](http://www.cvlibs.net/download.php?file=data_object_image_2.zip) and, the training labels for the object dataset from [here](http://www.cvlibs.net/download.php?file=data_object_label_2.zip), and place the zip files in `$DATA_DOWNLOAD_DIR`
#
# The data will then be extracted to have
# * training images in `$DATA_DOWNLOAD_DIR/training/image_2`
# * training labels in `$DATA_DOWNLOAD_DIR/training/label_2`
# * testing images in `$DATA_DOWNLOAD_DIR/testing/image_2`
#
# *Note: There are no labels for the testing images, therefore we use it just to visualize inferences for the trained model.*

# %% [markdown]
# ### A. Verify downloaded dataset <a class="anchor" id="head-1-1"></a>

# %%
# Check the dataset is present
# !mkdir -p $DATA_DOWNLOAD_DIR
# !if [ ! -f $DATA_DOWNLOAD_DIR/data_object_image_2.zip ]; then echo 'Image zip file not found, please download.'; else echo 'Found Image zip file.';fi
# !if [ ! -f $DATA_DOWNLOAD_DIR/data_object_label_2.zip ]; then echo 'Label zip file not found, please download.'; else echo 'Found Labels zip file.';fi

# %%
# unpack downloaded datasets to $DATA_DOWNLOAD_DIR.
# The training images will be under $DATA_DOWNLOAD_DIR/training/image_2 and 
# labels will be under $DATA_DOWNLOAD_DIR/training/label_2.
# The testing images will be under $DATA_DOWNLOAD_DIR/testing/image_2.
# !unzip -u $DATA_DOWNLOAD_DIR/data_object_image_2.zip -d $DATA_DOWNLOAD_DIR
# !unzip -u $DATA_DOWNLOAD_DIR/data_object_label_2.zip -d $DATA_DOWNLOAD_DIR

# %%
# verify
import os

DATA_DIR = os.environ.get('DATA_DOWNLOAD_DIR')
num_training_images = len(os.listdir(os.path.join(DATA_DIR, "training/image_2")))
num_training_labels = len(os.listdir(os.path.join(DATA_DIR, "training/label_2")))
num_testing_images = len(os.listdir(os.path.join(DATA_DIR, "testing/image_2")))
print("Number of images in the trainval set. {}".format(num_training_images))
print("Number of labels in the trainval set. {}".format(num_training_labels))
print("Number of images in the test set. {}".format(num_testing_images))

# %%
# Sample kitti label.
# !cat $DATA_DOWNLOAD_DIR/training/label_2/000110.txt

# %% [markdown]
# ### B. Prepare tf records from kitti format dataset <a class="anchor" id="head-1-2"></a>
#
# * Update the tfrecords spec file to take in your kitti format dataset
# * Create the tfrecords using the tlt-dataset-convert
#
# *Note: TfRecords only need to be generated once.*

# %%
print("TFrecords conversion spec file for kitti training")
# !cat $SPECS_DIR/detectnet_v2_tfrecords_kitti_trainval.txt
# Out:
# TFrecords conversion spec file for kitti training

# %%
# Creating a new directory for the output tfrecords dump.
print("Converting Tfrecords for kitti trainval dataset")
# !tlt-dataset-convert -d $SPECS_DIR/detectnet_v2_tfrecords_kitti_trainval.txt \
                     -o $DATA_DOWNLOAD_DIR/tfrecords/kitti_trainval/kitti_trainval
# Out:
# Converting Tfrecords for kitti trainval dataset
# Using TensorFlow backend.
# 2020-11-25 06:35:46,062 - iva.detectnet_v2.dataio.build_converter - INFO - Instantiating a kitti converter
# 2020-11-25 06:35:46,062 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Num images in
# Train: 185	Val: 30
# 2020-11-25 06:35:46,062 - iva.detectnet_v2.dataio.kitti_converter_lib - INFO - Validation data in partition 0. Hence, while choosing the validationset during training choose validation_fold 0.
# 2020-11-25 06:35:46,062 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 0
# /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/dataio/kitti_converter_lib.py:266: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 2020-11-25 06:35:46,069 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 1
# 2020-11-25 06:35:46,071 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 2
# 2020-11-25 06:35:46,073 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 3
# 2020-11-25 06:35:46,075 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 4
# 2020-11-25 06:35:46,077 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 5
# 2020-11-25 06:35:46,079 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 6
# 2020-11-25 06:35:46,081 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 7
# 2020-11-25 06:35:46,083 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 8
# 2020-11-25 06:35:46,085 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 0, shard 9
# 2020-11-25 06:35:46,088 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# taxi: 2
# franchised_bus_s_d: 2
# heavy_goods_vehicle: 2
# private_car: 21
# light_goods_vehicle: 4
#
# 2020-11-25 06:35:46,088 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 0
# 2020-11-25 06:35:46,099 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 1
# 2020-11-25 06:35:46,112 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 2
# 2020-11-25 06:35:46,123 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 3
# 2020-11-25 06:35:46,135 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 4
# 2020-11-25 06:35:46,150 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 5
# 2020-11-25 06:35:46,161 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 6
# 2020-11-25 06:35:46,173 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 7
# 2020-11-25 06:35:46,185 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 8
# 2020-11-25 06:35:46,197 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Writing partition 1, shard 9
# 2020-11-25 06:35:46,212 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# taxi: 11
# franchised_bus_s_d: 6
# heavy_goods_vehicle: 30
# private_car: 123
# light_goods_vehicle: 39
#
# 2020-11-25 06:35:46,212 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Cumulative object statistics
# 2020-11-25 06:35:46,212 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO -
# Wrote the following numbers of objects:
# taxi: 13
# franchised_bus_s_d: 8
# heavy_goods_vehicle: 32
# private_car: 144
# light_goods_vehicle: 43
#
# 2020-11-25 06:35:46,212 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Class map.
# Label in GT: Label in tfrecords file
# Taxi: taxi
# Franchised_Bus_S_D: franchised_bus_s_d
# Heavy_Goods_Vehicle: heavy_goods_vehicle
# Private_Car: private_car
# Light_Goods_Vehicle: light_goods_vehicle
# For the dataset_config in the experiment_spec, please use labels in the tfrecords file, while writing the classmap.
#
# 2020-11-25 06:35:46,212 - iva.detectnet_v2.dataio.dataset_converter_lib - INFO - Tfrecords generation complete.

# %%
# !ls -rlt $DATA_DOWNLOAD_DIR/tfrecords/kitti_trainval/
# Out:
# total 164
# -rw-r--r-- 1 root root  1823 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root  1896 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root  1832 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root  1825 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root  1824 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root  1832 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root  1824 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root  1839 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root  1824 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root  1833 Nov 25 06:35 kitti_trainval-fold-000-of-002-shard-00009-of-00010
# -rw-r--r-- 1 root root 11123 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00000-of-00010
# -rw-r--r-- 1 root root 10961 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00001-of-00010
# -rw-r--r-- 1 root root 11043 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00002-of-00010
# -rw-r--r-- 1 root root 11014 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00003-of-00010
# -rw-r--r-- 1 root root 11323 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00004-of-00010
# -rw-r--r-- 1 root root 11110 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00005-of-00010
# -rw-r--r-- 1 root root 11123 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00006-of-00010
# -rw-r--r-- 1 root root 11330 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00007-of-00010
# -rw-r--r-- 1 root root 11157 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00008-of-00010
# -rw-r--r-- 1 root root 14387 Nov 25 06:35 kitti_trainval-fold-001-of-002-shard-00009-of-00010

# %% [markdown]
# ### C. Download pre-trained model <a class="anchor" id="head-1-3"></a>
# Download the correct pretrained model from the NGC model registry for your experiment. Please note that for DetectNet_v2, the input is expected to be 0-1 normalized with input channels in RGB order. Therefore, for optimum results please download models with `*_detectnet_v2` in their name string. All other models expect input preprocessing with mean subtraction and input channels in BGR order. Thus, using them as pretrained weights may result in suboptimal performance.

# %%
# List models available in the model registry.
# !ngc registry model list nvidia/tlt_pretrained_detectnet_v2:*
# Out:
# Connection failed; retrying... (Retries left: 5)
# Connection failed; retrying... (Retries left: 4)
# ^C

# %%
# Create the target destination to download the model.
# !mkdir -p $USER_EXPERIMENT_DIR/pretrained_resnet10/

# %%
# Download the pretrained model from NGC
# !ngc registry model download-version nvidia/tlt_pretrained_detectnet_v2:resnet10 \
    --dest $USER_EXPERIMENT_DIR/pretrained_resnet10
# Out:
# Downloaded 35.47 MB in 11s, Download speed: 3.22 MB/s
# ----------------------------------------------------
# Transfer id: tlt_pretrained_detectnet_v2_vresnet10 Download status: Completed.
# Downloaded local path: /workspace/tlt-experiments/detectnet_v2/pretrained_resnet10/tlt_pretrained_detectnet_v2_vresnet10
# Total files downloaded: 1
# Total downloaded size: 35.47 MB
# Started at: 2020-11-18 07:33:39.794902
# Completed at: 2020-11-18 07:33:50.813099
# Duration taken: 11s
# ----------------------------------------------------

# %%
# !ls -rlt $USER_EXPERIMENT_DIR/pretrained_resnet10/tlt_pretrained_detectnet_v2_vresnet10
# Out:
# total 39264
# -rw------- 1 root root 40205392 Nov 18 07:33 resnet10.hdf5

# %% [markdown]
# ## 2. Provide training specification <a class="anchor" id="head-2"></a>
# * Tfrecords for the train datasets
#     * In order to use the newly generated tfrecords, update the dataset_config parameter in the spec file at `$SPECS_DIR/detectnet_v2_train_resnet18_kitti.txt`
#     * Update the fold number to use for evaluation. In case of random data split, please use fold `0` only
#     * For sequence-wise split, you may use any fold generated from the dataset convert tool
# * Pre-trained models
# * Augmentation parameters for on the fly data augmentation
# * Other training (hyper-)parameters such as batch size, number of epochs, learning rate etc.

# %%
# !cat $SPECS_DIR/detectnet_v2_train_resnet10_kitti.txt
# Out:
# cat: /workspace/examples/detectnet_v2/specs/detectnet_v2_train_resnet10_kitti.txt: No such file or directory

# %% [markdown]
# ## 3. Run TLT training <a class="anchor" id="head-3"></a>
# * Provide the sample spec file and the output directory location for models
#
# *Note: The training may take hours to complete. Also, the remaining notebook, assumes that the training was done in single-GPU mode. When run in multi-GPU mode, please expect to update the pruning and inference steps with new pruning thresholds and updated parameters in the clusterfile.json accordingly for optimum performance.*
#
# *Detectnet_v2 now supports restart from checkpoint. Incase, the training job is killed prematurely, you may resume training from the closest checkpoint by simply re-running the same command line. Please do make sure to use the same number of GPUs when restarting the training.*

# %%
# !tlt-train detectnet_v2 -e $SPECS_DIR/detectnet_v2_train_resnet10_kitti.txt \
                        -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned \
                        -k $KEY \
                        -n resnet10_detector
# Out:
# Using TensorFlow backend.
# 2020-11-25 06:58:16,356 [INFO] iva.detectnet_v2.scripts.train: Loading experiment spec at /home/jovyan/specs/detectnet_v2_train_resnet10_kitti.txt.
# 2020-11-25 06:58:16,358 [INFO] iva.detectnet_v2.spec_handler.spec_loader: Merging specification from /home/jovyan/specs/detectnet_v2_train_resnet10_kitti.txt
# 2020-11-25 06:58:16,412 [INFO] iva.detectnet_v2.scripts.train: Cannot iterate over exactly 185 samples with a batch size of 32; each epoch will therefore take one extra step.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 384, 1248) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 192, 624) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 192, 624) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 192, 624) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 96, 312)  36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 96, 312)  256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 96, 312)  0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 96, 312)  36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 96, 312)  4160        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 96, 312)  256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 64, 96, 312)  256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 96, 312)  0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 96, 312)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 48, 156) 73856       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 48, 156) 512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 48, 156) 0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 48, 156) 147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 48, 156) 8320        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 48, 156) 512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 128, 48, 156) 512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 48, 156) 0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 48, 156) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 256, 24, 78)  295168      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 256, 24, 78)  1024        block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 256, 24, 78)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 256, 24, 78)  590080      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 256, 24, 78)  33024       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 256, 24, 78)  1024        block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 256, 24, 78)  1024        block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256, 24, 78)  0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 256, 24, 78)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 512, 24, 78)  1180160     block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 512, 24, 78)  2048        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 512, 24, 78)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 512, 24, 78)  2359808     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 512, 24, 78)  131584      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 512, 24, 78)  2048        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 512, 24, 78)  2048        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 512, 24, 78)  0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 512, 24, 78)  0           add_4[0][0]
# __________________________________________________________________________________________________
# output_bbox (Conv2D)            (None, 20, 24, 78)   10260       block_4a_relu[0][0]
# __________________________________________________________________________________________________
# output_cov (Conv2D)             (None, 5, 24, 78)    2565        block_4a_relu[0][0]
# ==================================================================================================
# Total params: 4,931,673
# Trainable params: 4,925,785
# Non-trainable params: 5,888
# __________________________________________________________________________________________________
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-11-25 06:58:30,515 [INFO] iva.detectnet_v2.scripts.train: Found 185 samples in training set
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-11-25 06:58:53,010 [INFO] iva.detectnet_v2.scripts.train: Found 30 samples in validation set
# 2020-11-25 07:01:12,054 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 0/120: loss: 0.00038 Time taken: 0:00:00 ETA: 0:00:00
# 2020-11-25 07:01:27,133 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch
[INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 24/120: loss: 0.00032 Time taken: 0:00:02.357388 ETA: 0:03:46.309248
# 2020-11-25 07:02:35,847 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 80.900
# 2020-11-25 07:02:36,222 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 25/120: loss: 0.00032 Time taken: 0:00:02.386104 ETA: 0:03:46.679880
# 2020-11-25 07:02:38,543 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 26/120: loss: 0.00029 Time taken: 0:00:02.287786 ETA: 0:03:35.051884
# 2020-11-25 07:02:40,910 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 27/120: loss: 0.00031 Time taken: 0:00:02.377290 ETA: 0:03:41.087970
# 2020-11-25 07:02:43,262 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 28/120: loss: 0.00031 Time taken: 0:00:02.357027 ETA: 0:03:36.846484

# %%
print("For multi-GPU, please uncomment and run this instead. Change --gpus based on your machine.")
# Please check the output results directory. Please adjust the batch size and learning rate
# parameters if needed, to reproduce the single GPU accuracy.
# Please update the paths in the following steps to the models stored at
# $USER_EXPERIMENT_DIR/experiment_dir_unpruned_2gpu in the following steps.

# !tlt-train detectnet_v2 -e $SPECS_DIR/detectnet_v2_train_resnet10_kitti_2gpu.txt \
                         -r $USER_EXPERIMENT_DIR/experiment_dir_unpruned_2gpu \
                         -k $KEY \
                         -n resnet10_detector \
                         --gpus 2
# Out:
# For multi-GPU, please uncomment and run this instead. Change --gpus based on your machine.

# %%
print('Model for each epoch:')
print('---------------------')
# !ls -lh $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights

# %% [markdown]
# ## 4. Evaluate the trained model <a class="anchor" id="head-4"></a>

# %%
# !tlt-evaluate detectnet_v2 -e $SPECS_DIR/detectnet_v2_train_resnet18_kitti.txt\
                           -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/resnet18_detector.tlt \
                           -k $KEY

# %% [markdown]
# ## 5. Prune the trained model <a class="anchor" id="head-5"></a>
# * Specify pre-trained model
# * Equalization criterion (`Applicable for resnets and mobilenets`)
# * Threshold for pruning.
# * A key to save and load the model
# * Output directory to store the model
#
# *Usually, you just need to adjust `-pth` (threshold) for accuracy and model size trade off. Higher `pth` gives you smaller model (and thus higher inference speed) but worse accuracy. The threshold to use is depend on the dataset. A pth value `5.2e-6` is just a start point. If the retrain accuracy is good, you can increase this value to get smaller models. Otherwise, lower this value to get better accuracy.*
#
# *For some internal studies, we have noticed that a pth value of 0.01 is a good starting point for detectnet_v2 models.*

# %%
# Create an output directory if it doesn't exist.
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_pruned

# %%
# !tlt-prune -m $USER_EXPERIMENT_DIR/experiment_dir_unpruned/weights/resnet10_detector.tlt \
           -o $USER_EXPERIMENT_DIR/experiment_dir_pruned/resnet10_nopool_bn_detectnet_v2_pruned.tlt \
           -eq union \
           -pth 0.01 \
           -k $KEY
# Out:
# Using TensorFlow backend.
# 2020-11-18 09:09:05,083 [INFO] modulus.pruning.pruning: Exploring graph for retainable indices
# 2020-11-18 09:09:05,249 [INFO] modulus.pruning.pruning: Pruning model and appending pruned nodes to new graph
# 2020-11-18 09:09:10,535 [INFO] iva.common.magnet_prune: Pruning ratio (pruned model / original model): 0.614910396533

# %%
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_pruned/

# %% [markdown]
# ## 6. Retrain the pruned model <a class="anchor" id="head-6"></a>
# * Model needs to be re-trained to bring back accuracy after pruning
# * Specify re-training specification with pretrained weights as pruned model.
#
# *Note: For retraining, please set the `load_graph` option to `true` in the model_config to load the pruned model graph. Also, if after retraining, the model shows some decrease in mAP, it could be that the originally trained model, was pruned a little too much. Please try reducing the pruning threshold, thereby reducing the pruning ratio, and use the new model to retrain.*

# %%
# Printing the retrain experiment file. 
# Note: We have updated the experiment file to include the 
# newly pruned model as a pretrained weights and, the
# load_graph option is set to true 
# !cat $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt

# %%
# Retraining using the pruned model as pretrained weights 
# !tlt-train detectnet_v2 -e $SPECS_DIR/detectnet_v2_retrain_resnet10_kitti.txt \
                        -r $USER_EXPERIMENT_DIR/experiment_dir_retrain \
                        -k $KEY \
                        -n resnet10_detector_pruned
# Out:
# Using TensorFlow backend.
# 2020-11-18 09:14:20,750 [INFO] iva.detectnet_v2.scripts.train: Loading experiment spec at /workspace/examples/detectnet_v2/specs/detectnet_v2_retrain_resnet10_kitti.txt.
# 2020-11-18 09:14:20,751 [INFO] iva.detectnet_v2.spec_handler.spec_loader: Merging specification from /workspace/examples/detectnet_v2/specs/detectnet_v2_retrain_resnet10_kitti.txt
# 2020-11-18 09:14:20,797 [INFO] iva.detectnet_v2.scripts.train: Cannot iterate over exactly 185 samples with a batch size of 8; each epoch will therefore take one extra step.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 3, 384, 1248) 0
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 64, 192, 624) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# bn_conv1 (BatchNormalization)   (None, 64, 192, 624) 256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 64, 192, 624) 0           bn_conv1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_1 (Conv2D)        (None, 64, 96, 312)  36928       activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_1 (BatchNormalizati (None, 64, 96, 312)  256         block_1a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_1a_relu_1 (Activation)    (None, 64, 96, 312)  0           block_1a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_2 (Conv2D)        (None, 64, 96, 312)  36928       block_1a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_1a_conv_shortcut (Conv2D) (None, 64, 96, 312)  4160        activation_1[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_2 (BatchNormalizati (None, 64, 96, 312)  256         block_1a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_1a_bn_shortcut (BatchNorm (None, 64, 96, 312)  256         block_1a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 64, 96, 312)  0           block_1a_bn_2[0][0]
#                                                                  block_1a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_1a_relu (Activation)      (None, 64, 96, 312)  0           add_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_1 (Conv2D)        (None, 128, 48, 156) 73856       block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_1 (BatchNormalizati (None, 128, 48, 156) 512         block_2a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_2a_relu_1 (Activation)    (None, 128, 48, 156) 0           block_2a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_2 (Conv2D)        (None, 128, 48, 156) 147584      block_2a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_2a_conv_shortcut (Conv2D) (None, 128, 48, 156) 8320        block_1a_relu[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_2 (BatchNormalizati (None, 128, 48, 156) 512         block_2a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_2a_bn_shortcut (BatchNorm (None, 128, 48, 156) 512         block_2a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 48, 156) 0           block_2a_bn_2[0][0]
#                                                                  block_2a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_2a_relu (Activation)      (None, 128, 48, 156) 0           add_2[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_1 (Conv2D)        (None, 224, 24, 78)  258272      block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_1 (BatchNormalizati (None, 224, 24, 78)  896         block_3a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_3a_relu_1 (Activation)    (None, 224, 24, 78)  0           block_3a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_2 (Conv2D)        (None, 248, 24, 78)  500216      block_3a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_3a_conv_shortcut (Conv2D) (None, 248, 24, 78)  31992       block_2a_relu[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_2 (BatchNormalizati (None, 248, 24, 78)  992         block_3a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_3a_bn_shortcut (BatchNorm (None, 248, 24, 78)  992         block_3a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 248, 24, 78)  0           block_3a_bn_2[0][0]
#                                                                  block_3a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_3a_relu (Activation)      (None, 248, 24, 78)  0           add_3[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_1 (Conv2D)        (None, 272, 24, 78)  607376      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_1 (BatchNormalizati (None, 272, 24, 78)  1088        block_4a_conv_1[0][0]
# __________________________________________________________________________________________________
# block_4a_relu_1 (Activation)    (None, 272, 24, 78)  0           block_4a_bn_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_2 (Conv2D)        (None, 480, 24, 78)  1175520     block_4a_relu_1[0][0]
# __________________________________________________________________________________________________
# block_4a_conv_shortcut (Conv2D) (None, 480, 24, 78)  119520      block_3a_relu[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_2 (BatchNormalizati (None, 480, 24, 78)  1920        block_4a_conv_2[0][0]
# __________________________________________________________________________________________________
# block_4a_bn_shortcut (BatchNorm (None, 480, 24, 78)  1920        block_4a_conv_shortcut[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 480, 24, 78)  0           block_4a_bn_2[0][0]
#                                                                  block_4a_bn_shortcut[0][0]
# __________________________________________________________________________________________________
# block_4a_relu (Activation)      (None, 480, 24, 78)  0           add_4[0][0]
# __________________________________________________________________________________________________
# output_bbox (Conv2D)            (None, 20, 24, 78)   9620        block_4a_relu[0][0]
# __________________________________________________________________________________________________
# output_cov (Conv2D)             (None, 5, 24, 78)    2405        block_4a_relu[0][0]
# ==================================================================================================
# Total params: 3,032,537
# Trainable params: 3,027,353
# Non-trainable params: 5,184
# __________________________________________________________________________________________________
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-11-18 09:14:26,993 [INFO] iva.detectnet_v2.scripts.train: Found 185 samples in training set
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# target/truncation is not updated to match the crop areaif the dataset contains target/truncation.
# 2020-11-18 09:14:34,575 [INFO] iva.detectnet_v2.scripts.train: Found 30 samples in validation set
# 2020-11-18 09:15:18,782 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 0/200: loss: 0.00070 Time taken: 0:00:00 ETA: 0:00:00
# 2020-11-18 09:15:30,794 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 1/5.: 100%|█| 26/26 [00:00<00:00, 23
# Matching predictions to ground truth, class 2/5.: 100%|█| 15/15 [00:00<00:00, 12
# Matching predictions to ground truth, class 3/5.: 100%|█| 9/9 [00:00<00:00, 8396
# Matching predictions to ground truth, class 4/5.: 100%|█| 20/20 [00:00<00:00, 20
# Matching predictions to ground truth, class 5/5.: 100%|█| 72/72 [00:00<00:00, 21
# Epoch 1/200
# =========================
#
# Validation cost: 0.000006
# Mean average_precision (in %): nan
#
# class name             average precision (in %)
# -------------------  --------------------------
# franchised_bus_s_d                     nan
# heavy_goods_vehicle                     75
# light_goods_vehicle                     68.8889
# private_car                             51.8519
# taxi                                     0
#
# Median Inference Time: 0.009915
# 2020-11-18 09:15:33,106 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 1/200: loss: 0.00010 Time taken: 0:00:20.086918 ETA: 1:06:37.296682
# 2020-11-18 09:15:33,106 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 9.875
# 2020-11-18 09:15:37,008 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 2/200: loss: 0.00010 Time taken: 0:00:03.902230 ETA: 0:12:52.641540
# 2020-11-18 09:15:37,167 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 49.251
# 2020-11-18 09:15:40,921 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 3/200: loss: 0.00010 Time taken: 0:00:03.910845 ETA: 0:12:50.436465
# 2020-11-18 09:15:41,247 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 49.020
# 2020-11-18 09:15:44,838 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 4/200: loss: 0.00010 Time taken: 0:00:03.915677 ETA: 0:12:47.472692
# 2020-11-18 09:15:45,327 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 49.030
# 2020-11-18 09:15:48,765 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 5/200: loss: 0.00010 Time taken: 0:00:03.926993 ETA: 0:12:45.763635
# 2020-11-18 09:15:49,420 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 48.858
# 2020-11-18 09:15:52,679 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 6/200: loss: 0.00010 Time taken: 0:00:03.917593 ETA: 0:12:40.013042
# 2020-11-18 09:15:53,493 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 49.112
# 2020-11-18 09:15:56,598 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 7/200: loss: 0.00009 Time taken: 0:00:03.916621 ETA: 0:12:35.907853
# 2020-11-18 09:15:57,582 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 48.919
# 2020-11-18 09:16:00,531 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 8/200: loss: 0.00010 Time taken: 0:00:03.931501 ETA: 0:12:34.848192
# 2020-11-18 09:16:01,680 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 48.808
# 2020-11-18 09:16:04,466 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 9/200: loss: 0.00009 Time taken: 0:00:03.933531 ETA: 0:12:31.304421
# 2020-11-18 09:16:05,771 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 48.890
# 2020-11-18 09:16:10,679 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 10/200: loss: 0.00010 Time taken: 0:00:06.170005 ETA: 0:19:32.300950
# 2020-11-18 09:16:12,146 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 31.373
# 2020-11-18 09:16:14,433 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 1/5.: 100%|█| 30/30 [00:00<00:00, 30
# Matching predictions to ground truth, class 2/5.: 100%|█| 15/15 [00:00<00:00, 14
# Matching predictions to ground truth, class 3/5.: 100%|█| 17/17 [00:00<00:00, 17
[INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 50/200: loss: 0.00007 Time taken: 0:00:06.357384 ETA: 0:15:53.607600
# 2020-11-18 09:19:02,890 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 4/5.: 100%|█| 197/197 [00:00<00:00,
# Matching predictions to ground truth, class 5/5.: 100%|█| 135/135 [00:00<00:00,
# Epoch 51/200
# =========================
#
# Validation cost: 0.000372
# Mean average_precision (in %): 0.0000
#
# class name             average precision (in %)
# -------------------  --------------------------
# franchised_bus_s_d                            0
# heavy_goods_vehicle                           0
# light_goods_vehicle                           0
# private_car                                   0
# taxi                                          0
#
# Median Inference Time: 0.008387
# 2020-11-18 09:19:03,524 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 51/200: loss: 0.00008 Time taken: 0:00:04.414115 ETA: 0:10:57.703135
# 2020-11-18 09:19:03,524 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 43.693
# 2020-11-18 09:19:07,437 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 52/200: loss: 0.00008 Time taken: 0:00:03.909780 ETA: 0:09:38.647440
# 2020-11-18 09:19:07,598 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 49.091
# 2020-11-18 09:19:11,356 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 53/200: loss: 0.00009 Time taken: 0:00:03.914953 ETA: 0:09:35.498091
# 2020-11-18 09:19:11,685 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 48.948
# 2020-11-18 09:19:15,380 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 54/200: loss: 0.00008 Time taken: 0:00:04.028020 ETA: 0:09:48.090920
# 2020-11-18 09:19:15,875 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 47.727
# 2020-11-18 09:19:19,441 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 55/200: loss: 0.00008 Time taken: 0:00:04.050809 ETA: 0:09:47.367305
# 2020-11-18 09:19:20,112 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 47.212
# 2020-11-18 09:19:23,553 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 56/200: loss: 0.00007 Time taken: 0:00:04.117875 ETA: 0:09:52.974000
# 2020-11-18 09:19:24,404 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 46.599
# 2020-11-18 09:19:27,659 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 57/200: loss: 0.00008 Time taken: 0:00:04.105629 ETA: 0:09:47.104947
# 2020-11-18 09:19:28,673 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 46.852
# 2020-11-18 09:19:31,781 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 58/200: loss: 0.00009 Time taken: 0:00:04.114948 ETA: 0:09:44.322616
# 2020-11-18 09:19:32,987 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 46.363
# 2020-11-18 09:19:35,950 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 59/200: loss: 0.00007 Time taken: 0:00:04.160280 ETA: 0:09:46.599480
# 2020-11-18 09:19:37,333 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 46.020
# 2020-11-18 09:19:42,322 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 60/200: loss: 0.00009 Time taken: 0:00:06.359782 ETA: 0:14:50.369480
# 2020-11-18 09:19:43,785 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 30.997
# 2020-11-18 09:19:46,095 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 2/5.: 100%|█| 24/24 [00:00<00:00, 24
# Matching predictions to ground truth, class 3/5.: 100%|█| 121/121 [00:00<00:00,
# Matching predictions to ground truth, class 4/5.: 100%|█| 96/96 [00:00<00:00, 28
# Matching predictions to ground truth, class 5/5.: 100%|█| 261/261 [00:00<00:00,
# Epoch 61/200
# =========================
#
# Validation cost: 0.000046
# Mean average_precision (in %): 0.0000
#
# class name             average precision (in %)
# -------------------  --------------------------
# franchised_bus_s_d                            0
# heavy_goods_vehicle                           0
# light_goods_vehicle                           0
# private_car                                   0
# taxi                                          0
#
# Median Inference Time: 0.008487
# 2020-11-18 09:19:46,675 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 61/200: loss: 0.00007 Time taken: 0:00:04.380230 ETA: 0:10:08.851970
# 2020-11-18 09:19:48,307 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 44.228
# 2020-11-18 09:19:50,603 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch
[INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 29.401
# 2020-11-18 09:27:41,500 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 2/5.: 100%|█| 15/15 [00:00<00:00, 14
# Matching predictions to ground truth, class 3/5.: 100%|█| 25/25 [00:00<00:00, 24
# Matching predictions to ground truth, class 4/5.: 100%|█| 58/58 [00:00<00:00, 16
# Matching predictions to ground truth, class 5/5.: 100%|█| 157/157 [00:00<00:00,
# Epoch 161/200
# =========================
#
# Validation cost: 0.000013
# Mean average_precision (in %): 30.8572
#
# class name             average precision (in %)
# -------------------  --------------------------
# franchised_bus_s_d                        0
# heavy_goods_vehicle                      40
# light_goods_vehicle                      76
# private_car                              38.286
# taxi                                      0
#
# Median Inference Time: 0.008299
# 2020-11-18 09:27:42,015 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 161/200: loss: 0.00002 Time taken: 0:00:04.391198 ETA: 0:02:51.256722
# 2020-11-18 09:27:43,837 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 42.504
# 2020-11-18 09:27:46,478 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 162/200: loss: 0.00004 Time taken: 0:00:04.442861 ETA: 0:02:48.828718
# 2020-11-18 09:27:48,583 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 42.145
# 2020-11-18 09:27:51,075 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 163/200: loss: 0.00002 Time taken: 0:00:04.585918 ETA: 0:02:49.678966
# 2020-11-18 09:27:53,381 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.686
# 2020-11-18 09:27:55,680 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 164/200: loss: 0.00003 Time taken: 0:00:04.612305 ETA: 0:02:46.042980
# 2020-11-18 09:27:58,164 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.810
# 2020-11-18 09:28:00,274 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 165/200: loss: 0.00003 Time taken: 0:00:04.585203 ETA: 0:02:40.482105
# 2020-11-18 09:28:02,964 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.669
# 2020-11-18 09:28:04,871 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 166/200: loss: 0.00003 Time taken: 0:00:04.596570 ETA: 0:02:36.283380
# 2020-11-18 09:28:07,785 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.486
# 2020-11-18 09:28:09,534 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 167/200: loss: 0.00002 Time taken: 0:00:04.662312 ETA: 0:02:33.856296
# 2020-11-18 09:28:12,620 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.368
# 2020-11-18 09:28:14,163 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 168/200: loss: 0.00002 Time taken: 0:00:04.626982 ETA: 0:02:28.063424
# 2020-11-18 09:28:17,453 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.389
# 2020-11-18 09:28:18,782 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 169/200: loss: 0.00002 Time taken: 0:00:04.626579 ETA: 0:02:23.423949
# 2020-11-18 09:28:22,266 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.555
# 2020-11-18 09:28:25,623 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 170/200: loss: 0.00003 Time taken: 0:00:06.836476 ETA: 0:03:25.094280
# 2020-11-18 09:28:28,762 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 30.791
# 2020-11-18 09:28:29,483 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 2/5.: 100%|█| 11/11 [00:00<00:00, 10
# Matching predictions to ground truth, class 3/5.: 100%|█| 25/25 [00:00<00:00, 77
# Matching predictions to ground truth, class 4/5.: 100%|█| 60/60 [00:00<00:00, 68
# Matching predictions to ground truth, class 5/5.: 100%|█| 137/137 [00:00<00:00,
# Epoch 171/200
# =========================
#
# Validation cost: 0.000015
# Mean average_precision (in %): 28.6091
#
# class name             average precision (in %)
# -------------------  --------------------------
# franchised_bus_s_d                       0
# heavy_goods_vehicle                     57.3333
# light_goods_vehicle                     60
# private_car                             25.7122
# taxi                                     0
#
# Median Inference Time: 0.008539
# 2020-11-18 09:28:30,006 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 171/200: loss: 0.00003 Time taken: 0:00:04.411457 ETA: 0:02:07.932253
# 2020-11-18 09:28:33,730 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 40.255
# 2020-11-18 09:28:34,501 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch
[INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.531
# 2020-11-18 09:29:41,073 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 186/200: loss: 0.00005 Time taken: 0:00:04.648077 ETA: 0:01:05.073078
# 2020-11-18 09:29:43,012 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.250
# 2020-11-18 09:29:45,709 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 187/200: loss: 0.00003 Time taken: 0:00:04.638697 ETA: 0:01:00.303061
# 2020-11-18 09:29:47,858 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.267
# 2020-11-18 09:29:50,371 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 188/200: loss: 0.00003 Time taken: 0:00:04.656424 ETA: 0:00:55.877088
# 2020-11-18 09:29:52,694 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.361
# 2020-11-18 09:29:55,020 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 189/200: loss: 0.00002 Time taken: 0:00:04.640387 ETA: 0:00:51.044257
# 2020-11-18 09:29:57,543 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.246
# 2020-11-18 09:30:02,042 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 190/200: loss: 0.00004 Time taken: 0:00:07.030648 ETA: 0:01:10.306480
# 2020-11-18 09:30:04,323 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 29.499
# 2020-11-18 09:30:05,871 [INFO] iva.detectnet_v2.evaluation.evaluation: step 0 / 3, 0.00s/step
# Matching predictions to ground truth, class 2/5.: 100%|█| 7/7 [00:00<00:00, 7298
# Matching predictions to ground truth, class 3/5.: 100%|█| 24/24 [00:00<00:00, 23
# Matching predictions to ground truth, class 4/5.: 100%|█| 49/49 [00:00<00:00, 13
# Matching predictions to ground truth, class 5/5.: 100%|█| 124/124 [00:00<00:00,
# Epoch 191/200
# =========================
#
# Validation cost: 0.000013
# Mean average_precision (in %): 24.6500
#
# class name             average precision (in %)
# -------------------  --------------------------
# franchised_bus_s_d                       0
# heavy_goods_vehicle                     43.75
# light_goods_vehicle                     50
# private_car                             29.4998
# taxi                                     0
#
# Median Inference Time: 0.008504
# 2020-11-18 09:30:06,357 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 191/200: loss: 0.00003 Time taken: 0:00:04.345307 ETA: 0:00:39.107763
# 2020-11-18 09:30:09,127 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.639
# 2020-11-18 09:30:10,837 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 192/200: loss: 0.00003 Time taken: 0:00:04.446697 ETA: 0:00:35.573576
# 2020-11-18 09:30:13,917 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.759
# 2020-11-18 09:30:15,451 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 193/200: loss: 0.00003 Time taken: 0:00:04.614293 ETA: 0:00:32.300051
# 2020-11-18 09:30:18,712 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.704
# 2020-11-18 09:30:20,052 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 194/200: loss: 0.00003 Time taken: 0:00:04.610995 ETA: 0:00:27.665970
# 2020-11-18 09:30:23,516 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.642
# 2020-11-18 09:30:24,674 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/task_progress_monitor_hook.pyc: Epoch 195/200: loss: 0.00003 Time taken: 0:00:04.604686 ETA: 0:00:23.023430
# 2020-11-18 09:30:28,363 [INFO] /usr/local/lib/python2.7/dist-packages/iva/detectnet_v2/tfhooks/sample_counter_hook.pyc: Samples / sec: 41.264

# %%
# In order to run the retraining using multi-GPU, please uncomment this.
# Please check the output results directory. Please adjust the batch size and learning rate
# parameters if needed, to reproduce the single GPU accuracy.

# !tlt-train detectnet_v2 -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti_2gpu.txt \
#                         -r $USER_EXPERIMENT_DIR/experiment_dir_retrain_2gpu \
#                         -k $KEY \
#                         -n resnet18_detector_pruned \
#                         --gpus 2

# %%
# Listing the newly retrained model.
# !ls -rlt $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights

# %% [markdown]
# ## 7. Evaluate the retrained model <a class="anchor" id="head-7"></a>

# %% [markdown]
# This section evaluates the pruned and retrained model, using `tlt-evaluate`.

# %%
# !tlt-evaluate detectnet_v2 -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt \
                           -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/resnet18_detector_pruned.tlt \
                           -k $KEY

# %% [markdown]
# ## 8. Visualize inferences <a class="anchor" id="head-8"></a>
# In this section, we run the `tlt-infer` tool to generate inferences on the trained models. To render bboxes from more classes, please edit the spec file `detectnet_v2_inference_kitti_tlt.txt` to include all the classes you would like to visualize and edit the rest of the file accordingly.

# %%
# Running inference for detection on n images
# !tlt-infer detectnet_v2 -e $SPECS_DIR/detectnet_v2_inference_kitti_tlt.txt \
                        -o $USER_EXPERIMENT_DIR/tlt_infer_testing \
                        -i $DATA_DOWNLOAD_DIR/testing/image_2 \
                        -k $KEY

# %% [markdown]
# The `tlt-infer` tool produces two outputs.
# 1. Overlain images in `$USER_EXPERIMENT_DIR/tlt_infer_testing/images_annotated`
# 2. Frame by frame bbox labels in kitti format located in `$USER_EXPERIMENT_DIR/tlt_infer_testing/labels`
#
# *Note: To run inferences for a single image, simply replace the path to the -i flag in `tlt-infer` command with the path to the image.*

# %%
# Simple grid visualizer
import matplotlib.pyplot as plt
import os
from math import ceil
valid_image_ext = ['.jpg', '.png', '.jpeg', '.ppm']

def visualize_images(image_dir, num_cols=4, num_images=10):
    output_path = os.path.join(os.environ['USER_EXPERIMENT_DIR'], image_dir)
    num_rows = int(ceil(float(num_images) / float(num_cols)))
    f, axarr = plt.subplots(num_rows, num_cols, figsize=[80,30])
    f.tight_layout()
    a = [os.path.join(output_path, image) for image in os.listdir(output_path) 
         if os.path.splitext(image)[1].lower() in valid_image_ext]
    for idx, img_path in enumerate(a[:num_images]):
        col_id = idx % num_cols
        row_id = idx / num_cols
        img = plt.imread(img_path)
        axarr[row_id, col_id].imshow(img)

# %%
# Visualizing the first 12 images.
OUTPUT_PATH = 'tlt_infer_testing/images_annotated' # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)

# %% [markdown]
# ## 9. Deploy! <a class="anchor" id="head-9"></a>

# %%
# !mkdir -p $USER_EXPERIMENT_DIR/experiment_dir_final
# Removing a pre-existing copy of the etlt if there has been any.
import os
output_file=os.path.join(os.environ['USER_EXPERIMENT_DIR'],
                         "experiment_dir_final/resnet18_detector.etlt")
if os.path.exists(output_file):
    os.system("rm {}".format(output_file))
# !tlt-export detectnet_v2 \
            -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/resnet18_detector_pruned.tlt \
            -o $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt \
            -k $KEY

# %%
print('Exported model:')
print('------------')
# !ls -lh $USER_EXPERIMENT_DIR/experiment_dir_final

# %% [markdown]
# ### A. Int8 Optimization <a class="anchor" id="head-9-1"></a>
# DetectNet_v2 model supports int8 inference mode in TRT. In order to use int8 mode, we must calibrate the model to run 8-bit inferences. This involves 2 steps
#
# * Generate calibration tensorfile from the training data using tlt-int8-tensorfile
# * Use tlt-export to generate int8 calibration table.
#
# *Note: For this example, we generate a calibration tensorfile containing 10 batches of training data.
# Ideally, it is best to use atleast 10-20% of the training data to calibrate the model. The more data provided during calibration, the closer int8 inferences are to fp32 inferences.*

# %%
# !tlt-int8-tensorfile detectnet_v2 -e $SPECS_DIR/detectnet_v2_retrain_resnet18_kitti.txt \
                                  -m 10 \
                                  -o $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.tensor

# %%
# !rm -rf $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt
# !tlt-export detectnet_v2 \
            -m $USER_EXPERIMENT_DIR/experiment_dir_retrain/weights/resnet18_detector_pruned.tlt \
            -o $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt \
            -k $KEY  \
            --cal_data_file $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.tensor \
            --data_type int8 \
            --batches 10 \
            --batch_size 4 \
            --max_batch_size 4\
            --engine_file $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.trt.int8 \
            --cal_cache_file $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.bin \
            --verbose

# %% [markdown]
# ### B. Generate TensorRT engine <a class="anchor" id="head-9-2"></a>
# Verify engine generation using the `tlt-converter` utility included with the docker.
#
# The `tlt-converter` produces optimized tensorrt engines for the platform that it resides on. Therefore, to get maximum performance, please instantiate this docker and execute the `tlt-converter` command, with the exported `.etlt` file and calibration cache (for int8 mode) on your target device. The converter utility included in this docker only works for x86 devices, with discrete NVIDIA GPU's.
#
# For the jetson devices, please download the converter for jetson from the dev zone link [here](https://developer.nvidia.com/tlt-converter).
#
# If you choose to integrate your model into deepstream directly, you may do so by simply copying the exported `.etlt` file along with the calibration cache to the target device and updating the spec file that configures the `gst-nvinfer` element to point to this newly exported model. Usually this file is called `config_infer_primary.txt` for detection models and `config_infer_secondary_*.txt` for classification models.

# %%
# !tlt-converter $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.etlt \
               -k $KEY \
               -c $USER_EXPERIMENT_DIR/experiment_dir_final/calibration.bin \
               -o output_cov/Sigmoid,output_bbox/BiasAdd \
               -d 3,384,1248 \
               -i nchw \
               -m 64 \
               -t int8 \
               -e $USER_EXPERIMENT_DIR/experiment_dir_final/resnet18_detector.trt \
               -b 4

# %% [markdown]
# ## 10. Verify Deployed Model <a class="anchor" id="head-10"></a>
# Verify the exported model by visualizing inferences on TensorRT.
# In addition to running inference on a `.tlt` model in [step 8](#head-8), the `tlt-infer` tool is also capable of consuming the converted `TensorRT engine` from [step 9.B](#head-9-2).
#
# *If after int-8 calibration the accuracy of the int-8 inferences seem to degrade, it could be because the there wasn't enough data in the calibration tensorfile used to calibrate thee model or, the training data is not entirely representative of your test images, and the calibration maybe incorrect. Therefore, you may either regenerate the calibration tensorfile with more batches of the training data, and recalibrate the model, or calibrate the model on a few images from the test set. This may be done using `--cal_image_dir` flag in the `tlt-export` tool. For more information, please follow the instructions in the USER GUIDE.

# %% [markdown]
# ### A. Inference using TensorRT engine <a class="anchor" id="head-10-1"></a>

# %%
# !tlt-infer detectnet_v2 -e $SPECS_DIR/detectnet_v2_inference_kitti_etlt.txt \
                        -o $USER_EXPERIMENT_DIR/etlt_infer_testing \
                        -i $DATA_DOWNLOAD_DIR/testing/image_2 \
                        -k $KEY

# %%
# visualize the first 12 inferenced images.
OUTPUT_PATH = 'etlt_infer_testing/images_annotated' # relative path from $USER_EXPERIMENT_DIR.
COLS = 4 # number of columns in the visualizer grid.
IMAGES = 12 # number of images to visualize.

visualize_images(OUTPUT_PATH, num_cols=COLS, num_images=IMAGES)
